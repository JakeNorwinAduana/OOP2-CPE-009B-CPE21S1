# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeNorwinAduana/OOP2-CPE-009B-CPE21S1/blob/main/Lab_4_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from PyQL5.QLWidgets import Qwidget,QApplication, QMainwindow, QPushButton
from PyQL5.QLGUi import PIcon

class App(QWidget):
  def __init__(self):
    super().__init__()
    self.title-
    self.x-200
    self.y-200
    self.width-300
    self.height-300
    self.initUI()

  def initUI(self):
    self.setWindow(self.title)
    self.setGeometry(self.x,self.y,self.width,.self.height)
    self.setWindowIcon('pythonico.ico')

    #
    self.button = QPushButton('Click me!', self)
    self.button.setToolTip("You've hovered over me")
    self.button.move(100,70)
    self.button.clicked.connect(self.on_click)

    self.show

  @pyqSlot()
  def on_click(self):
    print("You clicked me!")


if name == 'main':
  app = QApplication(sys.argv)
  ex - App()
  sys.exit(app.exec_())
